# %% [markdown]
# <a href="https://colab.research.google.com/github/Aman237475/Brain_Tumor_MRI_Classification_TensorFlow_CNN/blob/main/Brain_Tumor_MRI_Classification_CNN%F0%9F%A7%A0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES
# TO THE CORRECT LOCATION (/kaggle/input) IN YOUR NOTEBOOK,
# THEN FEEL FREE TO DELETE THIS CELL.
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.

import os
import sys
from tempfile import NamedTemporaryFile
from urllib.request import urlopen
from urllib.parse import unquote, urlparse
from urllib.error import HTTPError
from zipfile import ZipFile
import tarfile
import shutil

CHUNK_SIZE = 40960
DATA_SOURCE_MAPPING = 'brain-tumor-classification-mri:https%3A%2F%2Fstorage.googleapis.com%2Fkaggle-data-sets%2F672377%2F1183165%2Fbundle%2Farchive.zip%3FX-Goog-Algorithm%3DGOOG4-RSA-SHA256%26X-Goog-Credential%3Dgcp-kaggle-com%2540kaggle-161607.iam.gserviceaccount.com%252F20240401%252Fauto%252Fstorage%252Fgoog4_request%26X-Goog-Date%3D20240401T185933Z%26X-Goog-Expires%3D259200%26X-Goog-SignedHeaders%3Dhost%26X-Goog-Signature%...'

KAGGLE_INPUT_PATH='/kaggle/input'
KAGGLE_WORKING_PATH='/kaggle/working'
KAGGLE_SYMLINK='kaggle'

# !umount /kaggle/input/ 2> /dev/null
shutil.rmtree('/kaggle/input', ignore_errors=True)
os.makedirs(KAGGLE_INPUT_PATH, 0o777, exist_ok=True)
os.makedirs(KAGGLE_WORKING_PATH, 0o777, exist_ok=True)

try:
  os.symlink(KAGGLE_INPUT_PATH, os.path.join("..", 'input'), target_is_directory=True)
except FileExistsError:
  pass
try:
  os.symlink(KAGGLE_WORKING_PATH, os.path.join("..", 'working'), target_is_directory=True)
except FileExistsError:
  pass

for data_source_mapping in DATA_SOURCE_MAPPING.split(','):
    directory, download_url_encoded = data_source_mapping.split(':')
    download_url = unquote(download_url_encoded)
    filename = urlparse(download_url).path
    destination_path = os.path.join(KAGGLE_INPUT_PATH, directory)
    try:
        with urlopen(download_url) as fileres, NamedTemporaryFile() as tfile:
            total_length = fileres.headers['content-length']
            print(f'Downloading {directory}, {total_length} bytes compressed')
            dl = 0
            data = fileres.read(CHUNK_SIZE)
            while len(data) > 0:
                dl += len(data)
                tfile.write(data)
                done = int(50 * dl / int(total_length))
                sys.stdout.write(f"\r[{'=' * done}{' ' * (50-done)}] {dl} bytes downloaded")
                sys.stdout.flush()
                data = fileres.read(CHUNK_SIZE)
            if filename.endswith('.zip'):
              with ZipFile(tfile) as zfile:
                zfile.extractall(destination_path)
            else:
              with tarfile.open(tfile.name) as tarfile:
                tarfile.extractall(destination_path)
            print(f'\nDownloaded and uncompressed: {directory}')
    except HTTPError as e:
        print(f'Failed to load (likely expired) {download_url} to path {destination_path}')
        continue
    except OSError as e:
        print(f'Failed to load {download_url} to path {destination_path}')
        continue

print('Data source import complete.')
# Out:
# Downloading brain-tumor-classification-mri, 91002358 bytes compressed
# [==================================================] 91002358 bytes downloaded
# Downloaded and uncompressed: brain-tumor-classification-mri
# Data source import complete.

# %% [markdown]
# # Introduction

# %% [markdown]
# In this notebook, I've used **CNN** to perform Image Classification on the Brain Tumor dataset.<br>
# Since this dataset is small, if we train a neural network to it, it won't really give us a good result.<br>
# Therefore, I'm going to use the concept of **Transfer Learning** to train the model to get really accurate results.

# %% [markdown]
# <img src="https://miro.medium.com/max/2800/1*TUF_YfybJPQ8WA0siWeJTg@2x.jpeg" alt="Brain" style="width: 800px;">

# %% [markdown]
# ### Note

# %% [markdown]
# If you find this notebook helpful and intuitive, feel free to upvote it! Do give me your suggestions or opinions so that I can improve my work! I will highly appreciate it! Thank you! :)

# %% [markdown]
# ---

# %% [markdown]
# # Importing Libraries

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import cv2
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tqdm import tqdm
import os
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, TensorBoard, ModelCheckpoint
from sklearn.metrics import classification_report,confusion_matrix
import ipywidgets as widgets
import io
from PIL import Image
from IPython.display import display,clear_output
from warnings import filterwarnings
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(4).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(23).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(88).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(60).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(52).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(51).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(13).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(71).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(96).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(61).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(87).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(66).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(91).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(73).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(99).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(42).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(112).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(48).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(46).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(21).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(62).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(120).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(106).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(19).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(68).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(75).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(57).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(80).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(18).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(70).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(76).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(2).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(63).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(53).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(64).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(14).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(35).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(38).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(86).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(36).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(82).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(83).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(6).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(100).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(11).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(41).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(1).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(37).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(123).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(5).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(121).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(17).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(7).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(125).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(81).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(3).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(28).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(27).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(85).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(79).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(34).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(45).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(44).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(92).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(93).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(8).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(43).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(10).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(77).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(98).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(126).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(20).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(25).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(124).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(72).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(58).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(15).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(24).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(54).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(127).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(118).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(29).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(32).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(95).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(30).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(74).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(26).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(113).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(55).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(40).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(107).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(109).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(102).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(22).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(59).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(9).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(69).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(33).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(90).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(12).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(84).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(89).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(39).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(97).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image.jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(65).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(50).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(67).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(56).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(16).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(31).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(47).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(49).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(78).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(94).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(4).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(23).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(88).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(60).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(52).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(51).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(13).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(71).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(61).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(87).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(66).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(91).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(73).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(99).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(42).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(48).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(46).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(21).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(62).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(19).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(68).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(75).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(57).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(80).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(18).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(70).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(76).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(2).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(63).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(53).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(64).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(14).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(35).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(38).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(86).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(36).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(82).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(83).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(6).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(100).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(11).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(41).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(1).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(37).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(5).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(17).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(7).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(81).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(3).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(28).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(27).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(85).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(79).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(34).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(45).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(44).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(92).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(93).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(8).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(43).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(10).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(77).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(98).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(20).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(25).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(72).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(58).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(15).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(24).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(54).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(29).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(32).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(95).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(30).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(74).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(26).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(55).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(40).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(22).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(59).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(9).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(69).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(33).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(90).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(12).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(84).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(89).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(39).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(97).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image.jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(65).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(50).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(67).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(56).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(16).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(31).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(47).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(49).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(78).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(94).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/pituitary_tumor/image(23).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/pituitary_tumor/image(88).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/pituitary_tumor/image(60).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/pituitary_tumor/image(52).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/pituitary_tumor/image(51).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/pituitary_tumor/image(13).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/pituitary_tumor/image(96).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/pituitary_tumor/image(61).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/pituitary_tumor/image(87).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/pituitary_tumor/image(66).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/pituitary_tumor/image(91).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/pituitary_tumor/image(73).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/pituitary_tumor/image(42).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/pituitary_tumor/image(48).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/pituitary_tumor/image(46).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/pituitary_tumor/image(21).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/pituitary_tumor/image(19).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/pituitary_tumor/image(68).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/pituitary_tumor/image(57).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/pituitary_tumor/image(18).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/pituitary_tumor/image(70).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/pituitary_tumor/image(76).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/pituitary_tumor/image(2).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/pituitary_tumor/image(63).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/pituitary_tumor/image(53).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/pituitary_tumor/image(64).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/pituitary_tumor/image(35).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/pituitary_tumor/image(38).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/pituitary_tumor/image(86).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/pituitary_tumor/image(36).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/pituitary_tumor/image(82).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/pituitary_tumor/image(6).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/pituitary_tumor/image(11).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/pituitary_tumor/image(41).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/pituitary_tumor/image(1).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/pituitary_tumor/image(37).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/pituitary_tumor/image(5).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/pituitary_tumor/image(7).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/pituitary_tumor/image(81).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/pituitary_tumor/image(3).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/pituitary_tumor/image(28).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/pituitary_tumor/image(27).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/pituitary_tumor/image(85).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/pituitary_tumor/image(79).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/pituitary_tumor/image(34).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/pituitary_tumor/image(45).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/pituitary_tumor/image(44).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/pituitary_tumor/image(92).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/pituitary_tumor/image(93).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/pituitary_tumor/image(8).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/pituitary_tumor/image(43).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/pituitary_tumor/image(10).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/pituitary_tumor/image(77).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/pituitary_tumor/image(98).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/pituitary_tumor/image(20).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/pituitary_tumor/image(15).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/pituitary_tumor/image(54).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/pituitary_tumor/image(95).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/pituitary_tumor/image(30).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/pituitary_tumor/image(55).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/pituitary_tumor/image(22).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/pituitary_tumor/image(69).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/pituitary_tumor/image(90).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/pituitary_tumor/image(89).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/pituitary_tumor/image(97).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/pituitary_tumor/image.jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/pituitary_tumor/image(65).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/pituitary_tumor/image(67).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/pituitary_tumor/image(56).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/pituitary_tumor/image(31).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/pituitary_tumor/image(47).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/pituitary_tumor/image(49).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/pituitary_tumor/image(78).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/pituitary_tumor/image(94).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(4).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(23).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(88).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(60).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(52).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(51).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(13).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(71).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(96).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(61).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(87).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(66).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(91).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(73).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(99).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(42).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(48).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(46).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(21).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(62).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(19).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(68).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(75).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(57).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(80).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(18).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(70).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(76).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(2).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(63).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(53).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(64).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(14).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(35).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(38).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(86).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(36).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(82).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(83).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(6).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(100).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(11).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(41).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(1).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(37).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(5).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(17).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(7).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(81).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(3).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(28).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(27).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(85).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(79).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(34).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(45).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(44).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(92).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(93).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(8).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(43).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(10).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(77).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(98).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(20).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(25).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(72).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(58).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(15).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(24).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(54).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(29).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(32).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(95).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(30).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(74).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(26).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(55).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(40).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(102).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(104).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(22).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(59).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(9).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(69).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(33).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(90).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(101).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(12).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(84).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(89).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(39).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(97).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image.jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(65).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(50).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(67).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(56).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(16).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(31).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(47).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(49).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(78).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(94).jpg
# /kaggle/input/brain-tumor-classification-mri/Testing/no_tumor/image(103).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m3 (36).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m1(83).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m1(48).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m1(75).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m2 (109).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m (49).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m (124).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m2 (95).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m3 (114).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m1(180).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m1(79).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m1(18).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m3 (23).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m1(196).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m2 (143).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m1(56).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m1(81).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m3 (147).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m1(86).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m3 (16).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m (196).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m (126).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m1(34).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m3 (237).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m1(190).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m (24).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m2 (140).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m3 (86).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m (20).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m (189).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m2 (4).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m3 (166).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m3 (207).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m3 (18).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m3 (240).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m3 (229).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m1(195).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m3 (40).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m (30).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m1(142).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m3 (125).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m2 (15).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m (88).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m1(38).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m3 (197).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m2 (139).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m2 (142).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m3 (97).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m (104).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m2 (126).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m2 (100).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m2 (27).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m1(133).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m3 (182).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m2 (123).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m3 (175).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m2 (32).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m3 (139).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m3 (10).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m3 (226).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m3 (14).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m3 (136).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m1(3).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m (65).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m3 (159).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m3 (2).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m2 (63).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m3 (192).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m2 (71).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m1(16).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m1(152).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m2 (133).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m (46).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m (22).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m (90).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m2 (166).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m3 (158).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m2 (119).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m1(136).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m2 (108).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m2 (105).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m (194).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m1(175).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m1(50).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m1(123).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m3 (75).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m3 (121).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m3 (55).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m (16).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m2 (53).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m (114).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m1(199).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m1(89).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m1(61).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m (155).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m3 (215).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m (95).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m1(53).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m2 (74).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m2 (1).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m (33).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m (36).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m (138).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m3 (210).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m3 (223).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m3 (19).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m2 (137).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m (145).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m3 (90).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m (70).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m2 (69).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m2 (16).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m1(129).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m3 (245).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m3 (4).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m3 (209).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m1(20).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m (118).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m (54).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m1(2).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m1(104).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m3 (64).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m (72).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m2 (94).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m1(140).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m (111).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m (64).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m1(87).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m1(170).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m (44).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m2 (85).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m (89).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m3 (233).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m1(194).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m3 (20).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m (25).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m (58).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m1(127).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m2 (46).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m3 (41).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m (79).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m1(5).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m2 (150).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m3 (124).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m (8).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m2 (173).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m1(114).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m2 (47).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m3 (100).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m2 (96).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m2 (111).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m1(42).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m1(121).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m1(146).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m2 (92).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m2 (29).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m3 (82).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m (181).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m3 (65).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m1(10).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m1(169).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m3 (45).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m1(119).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m3 (216).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m2 (51).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m (184).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m (14).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m1(193).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m2 (175).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m3 (188).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m3 (15).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m2 (57).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m (115).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m2 (160).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m2 (24).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m2 (120).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m1(116).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m1(144).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m1(186).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m1(108).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m3 (199).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m (161).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m3 (213).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m1(179).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m (66).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m1(44).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m1(55).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m3 (234).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m3 (7).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m2 (75).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m2 (41).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m3 (143).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m3 (191).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m2 (90).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/meningioma_tumor/m2 (89).jpg
# ...
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(93).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image (15).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(266).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image (29).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(247).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(210).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(209).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image (23).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(8).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(286).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(313).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image (50).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(235).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(43).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image (53).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(312).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(10).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(77).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(168).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(154).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(220).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(98).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(126).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(20).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image (11).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(25).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(242).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(124).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(72).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(320).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(140).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(58).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image (4).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(298).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(267).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(15).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(253).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image (16).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(326).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(265).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(175).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image (42).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image (52).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(24).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(238).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(216).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(54).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(127).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image (33).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image (51).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/5.jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image (56).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(208).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image (61).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(327).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(118).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(230).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(237).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(165).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image (7).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(160).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(310).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(29).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/2.jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(288).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(155).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image (25).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(236).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(32).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(95).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(223).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(225).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(136).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(240).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(201).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(249).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(30).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(150).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image (57).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(206).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(74).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(285).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(26).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(227).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(215).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(191).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(115).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(113).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image (43).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image (28).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(173).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(178).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(55).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(156).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image (8).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(204).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(280).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(141).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(130).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(196).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(164).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(170).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(122).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(186).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(40).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(317).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(241).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(323).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(107).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(102).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(179).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image (54).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image (21).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(302).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(129).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(104).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(222).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(158).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image (40).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(181).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(166).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(22).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(316).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(171).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image (35).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(59).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image (32).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(217).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image (55).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(134).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(291).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image (60).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(143).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(257).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(272).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(261).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(148).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/1.jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(9).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(315).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(69).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(33).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(90).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(234).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(101).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(174).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(260).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(12).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(296).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(207).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(84).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(283).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image (17).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(89).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image (9).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image (63).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image (12).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image (39).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(111).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(39).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(303).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image.jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(149).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(262).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(314).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(183).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image (49).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(252).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(287).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(193).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(259).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(258).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(197).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(273).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(318).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(145).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(65).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(319).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(231).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(50).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(67).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image (46).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(180).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(194).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(56).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image (14).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(195).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(255).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(290).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image (37).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(251).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(16).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(274).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(31).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(47).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(133).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(49).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(78).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(147).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(94).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(219).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(297).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(103).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(228).jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/7.jpg
# /kaggle/input/brain-tumor-classification-mri/Training/no_tumor/image(276).jpg

# %% [markdown]
# ---

# %% [markdown]
# # Color

# %%
colors_dark = ["#1F1F1F", "#313131", '#636363', '#AEAEAE', '#DADADA']
colors_red = ["#331313", "#582626", '#9E1717', '#D35151', '#E9B4B4']
colors_green = ['#01411C','#4B6F44','#4F7942','#74C365','#D0F0C0']

sns.palplot(colors_dark)
sns.palplot(colors_green)
sns.palplot(colors_red)

# %% [markdown]
# ---

# %% [markdown]
# # Data Preperation

# %%
labels = ['glioma_tumor','no_tumor','meningioma_tumor','pituitary_tumor']

# %% [markdown]
# We start off by appending all the images from the  directories into a Python list and then converting them into numpy arrays after resizing it.

# %%
X_train = []
y_train = []
image_size = 150
for i in labels:
    folderPath = os.path.join('../input/brain-tumor-classification-mri','Training',i)
    for j in tqdm(os.listdir(folderPath)):
        img = cv2.imread(os.path.join(folderPath,j))
        img = cv2.resize(img,(image_size, image_size))
        X_train.append(img)
        y_train.append(i)

for i in labels:
    folderPath = os.path.join('../input/brain-tumor-classification-mri','Testing',i)
    for j in tqdm(os.listdir(folderPath)):
        img = cv2.imread(os.path.join(folderPath,j))
        img = cv2.resize(img,(image_size,image_size))
        X_train.append(img)
        y_train.append(i)

X_train = np.array(X_train)
y_train = np.array(y_train)
# Out:
# 100%|██████████| 826/826 [00:02<00:00, 385.54it/s]
# 100%|██████████| 395/395 [00:01<00:00, 333.13it/s]
# 100%|██████████| 822/822 [00:02<00:00, 354.70it/s]
# 100%|██████████| 827/827 [00:02<00:00, 362.97it/s]
# 100%|██████████| 100/100 [00:00<00:00, 451.13it/s]
# 100%|██████████| 105/105 [00:00<00:00, 1196.76it/s]
# 100%|██████████| 115/115 [00:00<00:00, 644.24it/s]
# 100%|██████████| 74/74 [00:00<00:00, 199.19it/s]

# %%
k=0
fig, ax = plt.subplots(1,4,figsize=(20,20))
fig.text(s='Sample Image From Each Label',size=18,fontweight='bold',
             fontname='monospace',color=colors_dark[1],y=0.62,x=0.4,alpha=0.8)
for i in labels:
    j=0
    while True :
        if y_train[j]==i:
            ax[k].imshow(X_train[j])
            ax[k].set_title(y_train[j])
            ax[k].axis('off')
            k+=1
            break
        j+=1

# %%
X_train, y_train = shuffle(X_train,y_train, random_state=101)

# %%
X_train.shape
# Out:
# (3264, 150, 150, 3)

# %% [markdown]
# Dividing the dataset into **Training** and **Testing** sets.

# %%
X_train,X_test,y_train,y_test = train_test_split(X_train,y_train, test_size=0.1,random_state=101)

# %% [markdown]
# Performing **One Hot Encoding** on the labels after converting it into numerical values:

# %%
y_train_new = []
for i in y_train:
    y_train_new.append(labels.index(i))
y_train = y_train_new
y_train = tf.keras.utils.to_categorical(y_train)


y_test_new = []
for i in y_test:
    y_test_new.append(labels.index(i))
y_test = y_test_new
y_test = tf.keras.utils.to_categorical(y_test)

# %% [markdown]
# ---

# %% [markdown]
# # Transfer Learning

# %% [markdown]
# Deep convolutional neural network models may take days or even weeks to train on very large datasets.
#
# A way to short-cut this process is to re-use the model weights from pre-trained models that were developed for standard computer vision benchmark datasets, such as the ImageNet image recognition tasks. Top performing models can be downloaded and used directly, or integrated into a new model for your own computer vision problems.
#
# In this notebook, I'll be using the **EfficientNetB0** model which will use the weights from the **ImageNet** dataset.
#
# The include_top parameter is set to *False* so that the network doesn't include the top layer/ output layer from the pre-built model which allows us to add our own output layer depending upon our use case!

# %%
effnet = EfficientNetB0(weights='imagenet',include_top=False,input_shape=(image_size,image_size,3))
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 [==============================] - 0s 0us/step

# %% [markdown]
# **GlobalAveragePooling2D** -> This layer acts similar to the Max Pooling layer in CNNs, the only difference being is that it uses the Average values instead of the Max value while *pooling*. This really helps in decreasing the computational load on the machine while training.
# <br><br>
# **Dropout** -> This layer omits some of the neurons at each step from the layer making the neurons more independent from the neibouring neurons. It helps in avoiding overfitting. Neurons to be ommitted are selected at random. The **rate** parameter is the liklihood of a neuron activation being set to 0, thus dropping out the neuron
#
# **Dense** -> This is the output layer which classifies the image into 1 of the 4 possible classes. It uses the **softmax** function which is a generalization of the sigmoid function.

# %%
model = effnet.output
model = tf.keras.layers.GlobalAveragePooling2D()(model)
model = tf.keras.layers.Dropout(rate=0.5)(model)
model = tf.keras.layers.Dense(4,activation='softmax')(model)
model = tf.keras.models.Model(inputs=effnet.input, outputs = model)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 150, 150, 3)]        0         []
#
#  rescaling (Rescaling)       (None, 150, 150, 3)          0         ['input_1[0][0]']
#
#  normalization (Normalizati  (None, 150, 150, 3)          7         ['rescaling[0][0]']
#  on)
#
#  rescaling_1 (Rescaling)     (None, 150, 150, 3)          0         ['normalization[0][0]']
#
#  stem_conv_pad (ZeroPadding  (None, 151, 151, 3)          0         ['rescaling_1[0][0]']
#  2D)
#
#  stem_conv (Conv2D)          (None, 75, 75, 32)           864       ['stem_conv_pad[0][0]']
#
#  stem_bn (BatchNormalizatio  (None, 75, 75, 32)           128       ['stem_conv[0][0]']
#  n)
#
#  stem_activation (Activatio  (None, 75, 75, 32)           0         ['stem_bn[0][0]']
#  n)
#
#  block1a_dwconv (DepthwiseC  (None, 75, 75, 32)           288       ['stem_activation[0][0]']
#  onv2D)
#
#  block1a_bn (BatchNormaliza  (None, 75, 75, 32)           128       ['block1a_dwconv[0][0]']
#  tion)
#
#  block1a_activation (Activa  (None, 75, 75, 32)           0         ['block1a_bn[0][0]']
#  tion)
#
#  block1a_se_squeeze (Global  (None, 32)                   0         ['block1a_activation[0][0]']
#  AveragePooling2D)
#
#  block1a_se_reshape (Reshap  (None, 1, 1, 32)             0         ['block1a_se_squeeze[0][0]']
#  e)
#
#  block1a_se_reduce (Conv2D)  (None, 1, 1, 8)              264       ['block1a_se_reshape[0][0]']
#
#  block1a_se_expand (Conv2D)  (None, 1, 1, 32)             288       ['block1a_se_reduce[0][0]']
#
#  block1a_se_excite (Multipl  (None, 75, 75, 32)           0         ['block1a_activation[0][0]',
#  y)                                                                  'block1a_se_expand[0][0]']
#
#  block1a_project_conv (Conv  (None, 75, 75, 16)           512       ['block1a_se_excite[0][0]']
#  2D)
#
#  block1a_project_bn (BatchN  (None, 75, 75, 16)           64        ['block1a_project_conv[0][0]']
#  ormalization)
#
#  block2a_expand_conv (Conv2  (None, 75, 75, 96)           1536      ['block1a_project_bn[0][0]']
#  D)
#
#  block2a_expand_bn (BatchNo  (None, 75, 75, 96)           384       ['block2a_expand_conv[0][0]']
#  rmalization)
#
#  block2a_expand_activation   (None, 75, 75, 96)           0         ['block2a_expand_bn[0][0]']
#  (Activation)
#
#  block2a_dwconv_pad (ZeroPa  (None, 77, 77, 96)           0         ['block2a_expand_activation[0]
#  dding2D)                                                           [0]']
#
#  block2a_dwconv (DepthwiseC  (None, 38, 38, 96)           864       ['block2a_dwconv_pad[0][0]']
#  onv2D)
#
#  block2a_bn (BatchNormaliza  (None, 38, 38, 96)           384       ['block2a_dwconv[0][0]']
#  tion)
#
#  block2a_activation (Activa  (None, 38, 38, 96)           0         ['block2a_bn[0][0]']
#  tion)
#
#  block2a_se_squeeze (Global  (None, 96)                   0         ['block2a_activation[0][0]']
#  AveragePooling2D)
#
#  block2a_se_reshape (Reshap  (None, 1, 1, 96)             0         ['block2a_se_squeeze[0][0]']
#  e)
#
#  block2a_se_reduce (Conv2D)  (None, 1, 1, 4)              388       ['block2a_se_reshape[0][0]']
#
#  block2a_se_expand (Conv2D)  (None, 1, 1, 96)             480       ['block2a_se_reduce[0][0]']
#
#  block2a_se_excite (Multipl  (None, 38, 38, 96)           0         ['block2a_activation[0][0]',
#  y)                                                                  'block2a_se_expand[0][0]']
#
#  block2a_project_conv (Conv  (None, 38, 38, 24)           2304      ['block2a_se_excite[0][0]']
#  2D)
#
#  block2a_project_bn (BatchN  (None, 38, 38, 24)           96        ['block2a_project_conv[0][0]']
#  ormalization)
#
#  block2b_expand_conv (Conv2  (None, 38, 38, 144)          3456      ['block2a_project_bn[0][0]']
#  D)
#
#  block2b_expand_bn (BatchNo  (None, 38, 38, 144)          576       ['block2b_expand_conv[0][0]']
#  rmalization)
#
#  block2b_expand_activation   (None, 38, 38, 144)          0         ['block2b_expand_bn[0][0]']
#  (Activation)
#
#  block2b_dwconv (DepthwiseC  (None, 38, 38, 144)          1296      ['block2b_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block2b_bn (BatchNormaliza  (None, 38, 38, 144)          576       ['block2b_dwconv[0][0]']
#  tion)
#
#  block2b_activation (Activa  (None, 38, 38, 144)          0         ['block2b_bn[0][0]']
#  tion)
#
#  block2b_se_squeeze (Global  (None, 144)                  0         ['block2b_activation[0][0]']
#  AveragePooling2D)
#
#  block2b_se_reshape (Reshap  (None, 1, 1, 144)            0         ['block2b_se_squeeze[0][0]']
#  e)
#
#  block2b_se_reduce (Conv2D)  (None, 1, 1, 6)              870       ['block2b_se_reshape[0][0]']
#
#  block2b_se_expand (Conv2D)  (None, 1, 1, 144)            1008      ['block2b_se_reduce[0][0]']
#
#  block2b_se_excite (Multipl  (None, 38, 38, 144)          0         ['block2b_activation[0][0]',
#  y)                                                                  'block2b_se_expand[0][0]']
#
#  block2b_project_conv (Conv  (None, 38, 38, 24)           3456      ['block2b_se_excite[0][0]']
#  2D)
#
#  block2b_project_bn (BatchN  (None, 38, 38, 24)           96        ['block2b_project_conv[0][0]']
#  ormalization)
#
#  block2b_drop (Dropout)      (None, 38, 38, 24)           0         ['block2b_project_bn[0][0]']
#
#  block2b_add (Add)           (None, 38, 38, 24)           0         ['block2b_drop[0][0]',
#                                                                      'block2a_project_bn[0][0]']
#
#  block3a_expand_conv (Conv2  (None, 38, 38, 144)          3456      ['block2b_add[0][0]']
#  D)
#
#  block3a_expand_bn (BatchNo  (None, 38, 38, 144)          576       ['block3a_expand_conv[0][0]']
#  rmalization)
#
#  block3a_expand_activation   (None, 38, 38, 144)          0         ['block3a_expand_bn[0][0]']
#  (Activation)
#
#  block3a_dwconv_pad (ZeroPa  (None, 41, 41, 144)          0         ['block3a_expand_activation[0]
#  dding2D)                                                           [0]']
#
#  block3a_dwconv (DepthwiseC  (None, 19, 19, 144)          3600      ['block3a_dwconv_pad[0][0]']
#  onv2D)
#
#  block3a_bn (BatchNormaliza  (None, 19, 19, 144)          576       ['block3a_dwconv[0][0]']
#  tion)
#
#  block3a_activation (Activa  (None, 19, 19, 144)          0         ['block3a_bn[0][0]']
#  tion)
#
#  block3a_se_squeeze (Global  (None, 144)                  0         ['block3a_activation[0][0]']
#  AveragePooling2D)
#
#  block3a_se_reshape (Reshap  (None, 1, 1, 144)            0         ['block3a_se_squeeze[0][0]']
#  e)
#
#  block3a_se_reduce (Conv2D)  (None, 1, 1, 6)              870       ['block3a_se_reshape[0][0]']
#
#  block3a_se_expand (Conv2D)  (None, 1, 1, 144)            1008      ['block3a_se_reduce[0][0]']
#
#  block3a_se_excite (Multipl  (None, 19, 19, 144)          0         ['block3a_activation[0][0]',
#  y)                                                                  'block3a_se_expand[0][0]']
#
#  block3a_project_conv (Conv  (None, 19, 19, 40)           5760      ['block3a_se_excite[0][0]']
#  2D)
#
#  block3a_project_bn (BatchN  (None, 19, 19, 40)           160       ['block3a_project_conv[0][0]']
#  ormalization)
#
#  block3b_expand_conv (Conv2  (None, 19, 19, 240)          9600      ['block3a_project_bn[0][0]']
#  D)
#
#  block3b_expand_bn (BatchNo  (None, 19, 19, 240)          960       ['block3b_expand_conv[0][0]']
#  rmalization)
#
#  block3b_expand_activation   (None, 19, 19, 240)          0         ['block3b_expand_bn[0][0]']
#  (Activation)
#
#  block3b_dwconv (DepthwiseC  (None, 19, 19, 240)          6000      ['block3b_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block3b_bn (BatchNormaliza  (None, 19, 19, 240)          960       ['block3b_dwconv[0][0]']
#  tion)
#
#  block3b_activation (Activa  (None, 19, 19, 240)          0         ['block3b_bn[0][0]']
#  tion)
#
#  block3b_se_squeeze (Global  (None, 240)                  0         ['block3b_activation[0][0]']
#  AveragePooling2D)
#
#  block3b_se_reshape (Reshap  (None, 1, 1, 240)            0         ['block3b_se_squeeze[0][0]']
#  e)
#
#  block3b_se_reduce (Conv2D)  (None, 1, 1, 10)             2410      ['block3b_se_reshape[0][0]']
#
#  block3b_se_expand (Conv2D)  (None, 1, 1, 240)            2640      ['block3b_se_reduce[0][0]']
#
#  block3b_se_excite (Multipl  (None, 19, 19, 240)          0         ['block3b_activation[0][0]',
#  y)                                                                  'block3b_se_expand[0][0]']
#
#  block3b_project_conv (Conv  (None, 19, 19, 40)           9600      ['block3b_se_excite[0][0]']
#  2D)
#
#  block3b_project_bn (BatchN  (None, 19, 19, 40)           160       ['block3b_project_conv[0][0]']
#  ormalization)
#
#  block3b_drop (Dropout)      (None, 19, 19, 40)           0         ['block3b_project_bn[0][0]']
#
#  block3b_add (Add)           (None, 19, 19, 40)           0         ['block3b_drop[0][0]',
#                                                                      'block3a_project_bn[0][0]']
#
#  block4a_expand_conv (Conv2  (None, 19, 19, 240)          9600      ['block3b_add[0][0]']
#  D)
#
#  block4a_expand_bn (BatchNo  (None, 19, 19, 240)          960       ['block4a_expand_conv[0][0]']
#  rmalization)
#
#  block4a_expand_activation   (None, 19, 19, 240)          0         ['block4a_expand_bn[0][0]']
#  (Activation)
#
#  block4a_dwconv_pad (ZeroPa  (None, 21, 21, 240)          0         ['block4a_expand_activation[0]
#  dding2D)                                                           [0]']
#
#  block4a_dwconv (DepthwiseC  (None, 10, 10, 240)          2160      ['block4a_dwconv_pad[0][0]']
#  onv2D)
#
#  block4a_bn (BatchNormaliza  (None, 10, 10, 240)          960       ['block4a_dwconv[0][0]']
#  tion)
#
#  block4a_activation (Activa  (None, 10, 10, 240)          0         ['block4a_bn[0][0]']
#  tion)
#
#  block4a_se_squeeze (Global  (None, 240)                  0         ['block4a_activation[0][0]']
#  AveragePooling2D)
#
#  block4a_se_reshape (Reshap  (None, 1, 1, 240)            0         ['block4a_se_squeeze[0][0]']
#  e)
#
#  block4a_se_reduce (Conv2D)  (None, 1, 1, 10)             2410      ['block4a_se_reshape[0][0]']
#
#  block4a_se_expand (Conv2D)  (None, 1, 1, 240)            2640      ['block4a_se_reduce[0][0]']
#
#  block4a_se_excite (Multipl  (None, 10, 10, 240)          0         ['block4a_activation[0][0]',
#  y)                                                                  'block4a_se_expand[0][0]']
#
#  block4a_project_conv (Conv  (None, 10, 10, 80)           19200     ['block4a_se_excite[0][0]']
#  2D)
#
#  block4a_project_bn (BatchN  (None, 10, 10, 80)           320       ['block4a_project_conv[0][0]']
#  ormalization)
#
#  block4b_expand_conv (Conv2  (None, 10, 10, 480)          38400     ['block4a_project_bn[0][0]']
#  D)
#
#  block4b_expand_bn (BatchNo  (None, 10, 10, 480)          1920      ['block4b_expand_conv[0][0]']
#  rmalization)
#
#  block4b_expand_activation   (None, 10, 10, 480)          0         ['block4b_expand_bn[0][0]']
#  (Activation)
#
#  block4b_dwconv (DepthwiseC  (None, 10, 10, 480)          4320      ['block4b_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block4b_bn (BatchNormaliza  (None, 10, 10, 480)          1920      ['block4b_dwconv[0][0]']
#  tion)
#
#  block4b_activation (Activa  (None, 10, 10, 480)          0         ['block4b_bn[0][0]']
#  tion)
#
#  block4b_se_squeeze (Global  (None, 480)                  0         ['block4b_activation[0][0]']
#  AveragePooling2D)
#
#  block4b_se_reshape (Reshap  (None, 1, 1, 480)            0         ['block4b_se_squeeze[0][0]']
#  e)
#
#  block4b_se_reduce (Conv2D)  (None, 1, 1, 20)             9620      ['block4b_se_reshape[0][0]']
#
#  block4b_se_expand (Conv2D)  (None, 1, 1, 480)            10080     ['block4b_se_reduce[0][0]']
#
#  block4b_se_excite (Multipl  (None, 10, 10, 480)          0         ['block4b_activation[0][0]',
#  y)                                                                  'block4b_se_expand[0][0]']
#
#  block4b_project_conv (Conv  (None, 10, 10, 80)           38400     ['block4b_se_excite[0][0]']
#  2D)
#
#  block4b_project_bn (BatchN  (None, 10, 10, 80)           320       ['block4b_project_conv[0][0]']
#  ormalization)
#
#  block4b_drop (Dropout)      (None, 10, 10, 80)           0         ['block4b_project_bn[0][0]']
#
#  block4b_add (Add)           (None, 10, 10, 80)           0         ['block4b_drop[0][0]',
#                                                                      'block4a_project_bn[0][0]']
#
#  block4c_expand_conv (Conv2  (None, 10, 10, 480)          38400     ['block4b_add[0][0]']
#  D)
#
#  block4c_expand_bn (BatchNo  (None, 10, 10, 480)          1920      ['block4c_expand_conv[0][0]']
#  rmalization)
#
#  block4c_expand_activation   (None, 10, 10, 480)          0         ['block4c_expand_bn[0][0]']
#  (Activation)
#
#  block4c_dwconv (DepthwiseC  (None, 10, 10, 480)          4320      ['block4c_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block4c_bn (BatchNormaliza  (None, 10, 10, 480)          1920      ['block4c_dwconv[0][0]']
#  tion)
#
#  block4c_activation (Activa  (None, 10, 10, 480)          0         ['block4c_bn[0][0]']
#  tion)
#
#  block4c_se_squeeze (Global  (None, 480)                  0         ['block4c_activation[0][0]']
#  AveragePooling2D)
#
#  block4c_se_reshape (Reshap  (None, 1, 1, 480)            0         ['block4c_se_squeeze[0][0]']
#  e)
#
#  block4c_se_reduce (Conv2D)  (None, 1, 1, 20)             9620      ['block4c_se_reshape[0][0]']
#
#  block4c_se_expand (Conv2D)  (None, 1, 1, 480)            10080     ['block4c_se_reduce[0][0]']
#
#  block4c_se_excite (Multipl  (None, 10, 10, 480)          0         ['block4c_activation[0][0]',
#  y)                                                                  'block4c_se_expand[0][0]']
#
#  block4c_project_conv (Conv  (None, 10, 10, 80)           38400     ['block4c_se_excite[0][0]']
#  2D)
#
#  block4c_project_bn (BatchN  (None, 10, 10, 80)           320       ['block4c_project_conv[0][0]']
#  ormalization)
#
#  block4c_drop (Dropout)      (None, 10, 10, 80)           0         ['block4c_project_bn[0][0]']
#
#  block4c_add (Add)           (None, 10, 10, 80)           0         ['block4c_drop[0][0]',
#                                                                      'block4b_add[0][0]']
#
#  block5a_expand_conv (Conv2  (None, 10, 10, 480)          38400     ['block4c_add[0][0]']
#  D)
#
#  block5a_expand_bn (BatchNo  (None, 10, 10, 480)          1920      ['block5a_expand_conv[0][0]']
#  rmalization)
#
#  block5a_expand_activation   (None, 10, 10, 480)          0         ['block5a_expand_bn[0][0]']
#  (Activation)
#
#  block5a_dwconv (DepthwiseC  (None, 10, 10, 480)          12000     ['block5a_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block5a_bn (BatchNormaliza  (None, 10, 10, 480)          1920      ['block5a_dwconv[0][0]']
#  tion)
#
#  block5a_activation (Activa  (None, 10, 10, 480)          0         ['block5a_bn[0][0]']
#  tion)
#
#  block5a_se_squeeze (Global  (None, 480)                  0         ['block5a_activation[0][0]']
#  AveragePooling2D)
#
#  block5a_se_reshape (Reshap  (None, 1, 1, 480)            0         ['block5a_se_squeeze[0][0]']
#  e)
#
#  block5a_se_reduce (Conv2D)  (None, 1, 1, 20)             9620      ['block5a_se_reshape[0][0]']
#
#  block5a_se_expand (Conv2D)  (None, 1, 1, 480)            10080     ['block5a_se_reduce[0][0]']
#
#  block5a_se_excite (Multipl  (None, 10, 10, 480)          0         ['block5a_activation[0][0]',
#  y)                                                                  'block5a_se_expand[0][0]']
#
#  block5a_project_conv (Conv  (None, 10, 10, 112)          53760     ['block5a_se_excite[0][0]']
#  2D)
#
#  block5a_project_bn (BatchN  (None, 10, 10, 112)          448       ['block5a_project_conv[0][0]']
#  ormalization)
#
#  block5b_expand_conv (Conv2  (None, 10, 10, 672)          75264     ['block5a_project_bn[0][0]']
#  D)
#
#  block5b_expand_bn (BatchNo  (None, 10, 10, 672)          2688      ['block5b_expand_conv[0][0]']
#  rmalization)
#
#  block5b_expand_activation   (None, 10, 10, 672)          0         ['block5b_expand_bn[0][0]']
#  (Activation)
#
#  block5b_dwconv (DepthwiseC  (None, 10, 10, 672)          16800     ['block5b_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block5b_bn (BatchNormaliza  (None, 10, 10, 672)          2688      ['block5b_dwconv[0][0]']
#  tion)
#
#  block5b_activation (Activa  (None, 10, 10, 672)          0         ['block5b_bn[0][0]']
#  tion)
#
#  block5b_se_squeeze (Global  (None, 672)                  0         ['block5b_activation[0][0]']
#  AveragePooling2D)
#
#  block5b_se_reshape (Reshap  (None, 1, 1, 672)            0         ['block5b_se_squeeze[0][0]']
#  e)
#
#  block5b_se_reduce (Conv2D)  (None, 1, 1, 28)             18844     ['block5b_se_reshape[0][0]']
#
#  block5b_se_expand (Conv2D)  (None, 1, 1, 672)            19488     ['block5b_se_reduce[0][0]']
#
#  block5b_se_excite (Multipl  (None, 10, 10, 672)          0         ['block5b_activation[0][0]',
#  y)                                                                  'block5b_se_expand[0][0]']
#
#  block5b_project_conv (Conv  (None, 10, 10, 112)          75264     ['block5b_se_excite[0][0]']
#  2D)
#
#  block5b_project_bn (BatchN  (None, 10, 10, 112)          448       ['block5b_project_conv[0][0]']
#  ormalization)
#
#  block5b_drop (Dropout)      (None, 10, 10, 112)          0         ['block5b_project_bn[0][0]']
#
#  block5b_add (Add)           (None, 10, 10, 112)          0         ['block5b_drop[0][0]',
#                                                                      'block5a_project_bn[0][0]']
#
#  block5c_expand_conv (Conv2  (None, 10, 10, 672)          75264     ['block5b_add[0][0]']
#  D)
#
#  block5c_expand_bn (BatchNo  (None, 10, 10, 672)          2688      ['block5c_expand_conv[0][0]']
#  rmalization)
#
#  block5c_expand_activation   (None, 10, 10, 672)          0         ['block5c_expand_bn[0][0]']
#  (Activation)
#
#  block5c_dwconv (DepthwiseC  (None, 10, 10, 672)          16800     ['block5c_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block5c_bn (BatchNormaliza  (None, 10, 10, 672)          2688      ['block5c_dwconv[0][0]']
#  tion)
#
#  block5c_activation (Activa  (None, 10, 10, 672)          0         ['block5c_bn[0][0]']
#  tion)
#
#  block5c_se_squeeze (Global  (None, 672)                  0         ['block5c_activation[0][0]']
#  AveragePooling2D)
#
#  block5c_se_reshape (Reshap  (None, 1, 1, 672)            0         ['block5c_se_squeeze[0][0]']
#  e)
#
#  block5c_se_reduce (Conv2D)  (None, 1, 1, 28)             18844     ['block5c_se_reshape[0][0]']
#
#  block5c_se_expand (Conv2D)  (None, 1, 1, 672)            19488     ['block5c_se_reduce[0][0]']
#
#  block5c_se_excite (Multipl  (None, 10, 10, 672)          0         ['block5c_activation[0][0]',
#  y)                                                                  'block5c_se_expand[0][0]']
#
#  block5c_project_conv (Conv  (None, 10, 10, 112)          75264     ['block5c_se_excite[0][0]']
#  2D)
#
#  block5c_project_bn (BatchN  (None, 10, 10, 112)          448       ['block5c_project_conv[0][0]']
#  ormalization)
#
#  block5c_drop (Dropout)      (None, 10, 10, 112)          0         ['block5c_project_bn[0][0]']
#
#  block5c_add (Add)           (None, 10, 10, 112)          0         ['block5c_drop[0][0]',
#                                                                      'block5b_add[0][0]']
#
#  block6a_expand_conv (Conv2  (None, 10, 10, 672)          75264     ['block5c_add[0][0]']
#  D)
#
#  block6a_expand_bn (BatchNo  (None, 10, 10, 672)          2688      ['block6a_expand_conv[0][0]']
#  rmalization)
#
#  block6a_expand_activation   (None, 10, 10, 672)          0         ['block6a_expand_bn[0][0]']
#  (Activation)
#
#  block6a_dwconv_pad (ZeroPa  (None, 13, 13, 672)          0         ['block6a_expand_activation[0]
#  dding2D)                                                           [0]']
#
#  block6a_dwconv (DepthwiseC  (None, 5, 5, 672)            16800     ['block6a_dwconv_pad[0][0]']
#  onv2D)
#
#  block6a_bn (BatchNormaliza  (None, 5, 5, 672)            2688      ['block6a_dwconv[0][0]']
#  tion)
#
#  block6a_activation (Activa  (None, 5, 5, 672)            0         ['block6a_bn[0][0]']
#  tion)
#
#  block6a_se_squeeze (Global  (None, 672)                  0         ['block6a_activation[0][0]']
#  AveragePooling2D)
#
# ...
#  block6b_se_reshape (Reshap  (None, 1, 1, 1152)           0         ['block6b_se_squeeze[0][0]']
#  e)
#
#  block6b_se_reduce (Conv2D)  (None, 1, 1, 48)             55344     ['block6b_se_reshape[0][0]']
#
#  block6b_se_expand (Conv2D)  (None, 1, 1, 1152)           56448     ['block6b_se_reduce[0][0]']
#
#  block6b_se_excite (Multipl  (None, 5, 5, 1152)           0         ['block6b_activation[0][0]',
#  y)                                                                  'block6b_se_expand[0][0]']
#
#  block6b_project_conv (Conv  (None, 5, 5, 192)            221184    ['block6b_se_excite[0][0]']
#  2D)
#
#  block6b_project_bn (BatchN  (None, 5, 5, 192)            768       ['block6b_project_conv[0][0]']
#  ormalization)
#
#  block6b_drop (Dropout)      (None, 5, 5, 192)            0         ['block6b_project_bn[0][0]']
#
#  block6b_add (Add)           (None, 5, 5, 192)            0         ['block6b_drop[0][0]',
#                                                                      'block6a_project_bn[0][0]']
#
#  block6c_expand_conv (Conv2  (None, 5, 5, 1152)           221184    ['block6b_add[0][0]']
#  D)
#
#  block6c_expand_bn (BatchNo  (None, 5, 5, 1152)           4608      ['block6c_expand_conv[0][0]']
#  rmalization)
#
#  block6c_expand_activation   (None, 5, 5, 1152)           0         ['block6c_expand_bn[0][0]']
#  (Activation)
#
#  block6c_dwconv (DepthwiseC  (None, 5, 5, 1152)           28800     ['block6c_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block6c_bn (BatchNormaliza  (None, 5, 5, 1152)           4608      ['block6c_dwconv[0][0]']
#  tion)
#
#  block6c_activation (Activa  (None, 5, 5, 1152)           0         ['block6c_bn[0][0]']
#  tion)
#
#  block6c_se_squeeze (Global  (None, 1152)                 0         ['block6c_activation[0][0]']
#  AveragePooling2D)
#
#  block6c_se_reshape (Reshap  (None, 1, 1, 1152)           0         ['block6c_se_squeeze[0][0]']
#  e)
#
#  block6c_se_reduce (Conv2D)  (None, 1, 1, 48)             55344     ['block6c_se_reshape[0][0]']
#
#  block6c_se_expand (Conv2D)  (None, 1, 1, 1152)           56448     ['block6c_se_reduce[0][0]']
#
#  block6c_se_excite (Multipl  (None, 5, 5, 1152)           0         ['block6c_activation[0][0]',
#  y)                                                                  'block6c_se_expand[0][0]']
#
#  block6c_project_conv (Conv  (None, 5, 5, 192)            221184    ['block6c_se_excite[0][0]']
#  2D)
#
#  block6c_project_bn (BatchN  (None, 5, 5, 192)            768       ['block6c_project_conv[0][0]']
#  ormalization)
#
#  block6c_drop (Dropout)      (None, 5, 5, 192)            0         ['block6c_project_bn[0][0]']
#
#  block6c_add (Add)           (None, 5, 5, 192)            0         ['block6c_drop[0][0]',
#                                                                      'block6b_add[0][0]']
#
#  block6d_expand_conv (Conv2  (None, 5, 5, 1152)           221184    ['block6c_add[0][0]']
#  D)
#
#  block6d_expand_bn (BatchNo  (None, 5, 5, 1152)           4608      ['block6d_expand_conv[0][0]']
#  rmalization)
#
#  block6d_expand_activation   (None, 5, 5, 1152)           0         ['block6d_expand_bn[0][0]']
#  (Activation)
#
#  block6d_dwconv (DepthwiseC  (None, 5, 5, 1152)           28800     ['block6d_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block6d_bn (BatchNormaliza  (None, 5, 5, 1152)           4608      ['block6d_dwconv[0][0]']
#  tion)
#
#  block6d_activation (Activa  (None, 5, 5, 1152)           0         ['block6d_bn[0][0]']
#  tion)
#
#  block6d_se_squeeze (Global  (None, 1152)                 0         ['block6d_activation[0][0]']
#  AveragePooling2D)
#
#  block6d_se_reshape (Reshap  (None, 1, 1, 1152)           0         ['block6d_se_squeeze[0][0]']
#  e)
#
#  block6d_se_reduce (Conv2D)  (None, 1, 1, 48)             55344     ['block6d_se_reshape[0][0]']
#
#  block6d_se_expand (Conv2D)  (None, 1, 1, 1152)           56448     ['block6d_se_reduce[0][0]']
#
#  block6d_se_excite (Multipl  (None, 5, 5, 1152)           0         ['block6d_activation[0][0]',
#  y)                                                                  'block6d_se_expand[0][0]']
#
#  block6d_project_conv (Conv  (None, 5, 5, 192)            221184    ['block6d_se_excite[0][0]']
#  2D)
#
#  block6d_project_bn (BatchN  (None, 5, 5, 192)            768       ['block6d_project_conv[0][0]']
#  ormalization)
#
#  block6d_drop (Dropout)      (None, 5, 5, 192)            0         ['block6d_project_bn[0][0]']
#
#  block6d_add (Add)           (None, 5, 5, 192)            0         ['block6d_drop[0][0]',
#                                                                      'block6c_add[0][0]']
#
#  block7a_expand_conv (Conv2  (None, 5, 5, 1152)           221184    ['block6d_add[0][0]']
#  D)
#
#  block7a_expand_bn (BatchNo  (None, 5, 5, 1152)           4608      ['block7a_expand_conv[0][0]']
#  rmalization)
#
#  block7a_expand_activation   (None, 5, 5, 1152)           0         ['block7a_expand_bn[0][0]']
#  (Activation)
#
#  block7a_dwconv (DepthwiseC  (None, 5, 5, 1152)           10368     ['block7a_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block7a_bn (BatchNormaliza  (None, 5, 5, 1152)           4608      ['block7a_dwconv[0][0]']
#  tion)
#
#  block7a_activation (Activa  (None, 5, 5, 1152)           0         ['block7a_bn[0][0]']
#  tion)
#
#  block7a_se_squeeze (Global  (None, 1152)                 0         ['block7a_activation[0][0]']
#  AveragePooling2D)
#
#  block7a_se_reshape (Reshap  (None, 1, 1, 1152)           0         ['block7a_se_squeeze[0][0]']
#  e)
#
#  block7a_se_reduce (Conv2D)  (None, 1, 1, 48)             55344     ['block7a_se_reshape[0][0]']
#
#  block7a_se_expand (Conv2D)  (None, 1, 1, 1152)           56448     ['block7a_se_reduce[0][0]']
#
#  block7a_se_excite (Multipl  (None, 5, 5, 1152)           0         ['block7a_activation[0][0]',
#  y)                                                                  'block7a_se_expand[0][0]']
#
#  block7a_project_conv (Conv  (None, 5, 5, 320)            368640    ['block7a_se_excite[0][0]']
#  2D)
#
#  block7a_project_bn (BatchN  (None, 5, 5, 320)            1280      ['block7a_project_conv[0][0]']
#  ormalization)
#
#  top_conv (Conv2D)           (None, 5, 5, 1280)           409600    ['block7a_project_bn[0][0]']
#
#  top_bn (BatchNormalization  (None, 5, 5, 1280)           5120      ['top_conv[0][0]']
#  )
#
#  top_activation (Activation  (None, 5, 5, 1280)           0         ['top_bn[0][0]']
#  )
#
#  global_average_pooling2d (  (None, 1280)                 0         ['top_activation[0][0]']
#  GlobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 1280)                 0         ['global_average_pooling2d[0][
#                                                                     0]']
#
#  dense (Dense)               (None, 4)                    5124      ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 4054695 (15.47 MB)
# Trainable params: 4012672 (15.31 MB)
# Non-trainable params: 42023 (164.16 KB)
# __________________________________________________________________________________________________

# %% [markdown]
# We finally compile our model.

# %%
model.compile(loss='categorical_crossentropy',optimizer = 'Adam', metrics= ['accuracy'])

# %% [markdown]
# **Callbacks** -> Callbacks can help you fix bugs more quickly, and can help you build better models. They can help you visualize how your model’s training is going, and can even help prevent overfitting by implementing early stopping or customizing the learning rate on each iteration.<br><br>
# By definition, "A callback is a set of functions to be applied at given stages of the training procedure. You can use callbacks to get a view on internal states and statistics of the model during training."
#
# In this notebook, I'll be using **TensorBoard, ModelCheckpoint and ReduceLROnPlateau** callback functions

# %%
tensorboard = TensorBoard(log_dir = 'logs')
checkpoint = ModelCheckpoint("effnet.h5",monitor="val_accuracy",save_best_only=True,mode="auto",verbose=1)
reduce_lr = ReduceLROnPlateau(monitor = 'val_accuracy', factor = 0.3, patience = 2, min_delta = 0.001,
                              mode='auto',verbose=1)

# %% [markdown]
# ---

# %% [markdown]
# # Training The Model

# %% [markdown]
# **Note**: The training takes alot of time! ~ 2 hours for me (Using CPU)<br>
# Barely took 5 minutes with the GPU.

# %%
history = model.fit(X_train,y_train,validation_split=0.1, epochs =12, verbose=1, batch_size=32,
                   callbacks=[tensorboard,checkpoint,reduce_lr])
# Out:
# Epoch 1/12
# 83/83 [==============================] - ETA: 0s - loss: 0.4690 - accuracy: 0.8226
# Epoch 1: val_accuracy improved from -inf to 0.85374, saving model to effnet.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 83/83 [==============================] - 54s 191ms/step - loss: 0.4690 - accuracy: 0.8226 - val_loss: 0.5313 - val_accuracy: 0.8537 - lr: 0.0010
# Epoch 2/12
# 83/83 [==============================] - ETA: 0s - loss: 0.1799 - accuracy: 0.9414
# Epoch 2: val_accuracy improved from 0.85374 to 0.94218, saving model to effnet.h5
# 83/83 [==============================] - 12s 139ms/step - loss: 0.1799 - accuracy: 0.9414 - val_loss: 0.2854 - val_accuracy: 0.9422 - lr: 0.0010
# Epoch 3/12
# 83/83 [==============================] - ETA: 0s - loss: 0.1091 - accuracy: 0.9599
# Epoch 3: val_accuracy did not improve from 0.94218
# 83/83 [==============================] - 11s 130ms/step - loss: 0.1091 - accuracy: 0.9599 - val_loss: 0.4334 - val_accuracy: 0.9014 - lr: 0.0010
# Epoch 4/12
# 83/83 [==============================] - ETA: 0s - loss: 0.0969 - accuracy: 0.9709
# Epoch 4: val_accuracy did not improve from 0.94218
#
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 83/83 [==============================] - 11s 131ms/step - loss: 0.0969 - accuracy: 0.9709 - val_loss: 0.4346 - val_accuracy: 0.9048 - lr: 0.0010
# Epoch 5/12
# 83/83 [==============================] - ETA: 0s - loss: 0.0476 - accuracy: 0.9837
# Epoch 5: val_accuracy improved from 0.94218 to 0.95918, saving model to effnet.h5
# 83/83 [==============================] - 12s 141ms/step - loss: 0.0476 - accuracy: 0.9837 - val_loss: 0.1439 - val_accuracy: 0.9592 - lr: 3.0000e-04
# Epoch 6/12
# 83/83 [==============================] - ETA: 0s - loss: 0.0167 - accuracy: 0.9955
# Epoch 6: val_accuracy improved from 0.95918 to 0.96599, saving model to effnet.h5
# 83/83 [==============================] - 12s 142ms/step - loss: 0.0167 - accuracy: 0.9955 - val_loss: 0.1193 - val_accuracy: 0.9660 - lr: 3.0000e-04
# Epoch 7/12
# 83/83 [==============================] - ETA: 0s - loss: 0.0153 - accuracy: 0.9939
# Epoch 7: val_accuracy improved from 0.96599 to 0.97279, saving model to effnet.h5
# 83/83 [==============================] - 12s 143ms/step - loss: 0.0153 - accuracy: 0.9939 - val_loss: 0.1011 - val_accuracy: 0.9728 - lr: 3.0000e-04
# Epoch 8/12
# 83/83 [==============================] - ETA: 0s - loss: 0.0116 - accuracy: 0.9951
# Epoch 8: val_accuracy did not improve from 0.97279
# 83/83 [==============================] - 11s 133ms/step - loss: 0.0116 - accuracy: 0.9951 - val_loss: 0.0946 - val_accuracy: 0.9728 - lr: 3.0000e-04
# Epoch 9/12
# 83/83 [==============================] - ETA: 0s - loss: 0.0086 - accuracy: 0.9974
# Epoch 9: val_accuracy did not improve from 0.97279
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 83/83 [==============================] - 11s 132ms/step - loss: 0.0086 - accuracy: 0.9974 - val_loss: 0.0956 - val_accuracy: 0.9728 - lr: 3.0000e-04
# Epoch 10/12
# 83/83 [==============================] - ETA: 0s - loss: 0.0050 - accuracy: 0.9985
# Epoch 10: val_accuracy improved from 0.97279 to 0.97959, saving model to effnet.h5
# 83/83 [==============================] - 12s 140ms/step - loss: 0.0050 - accuracy: 0.9985 - val_loss: 0.0912 - val_accuracy: 0.9796 - lr: 9.0000e-05
# Epoch 11/12
# 83/83 [==============================] - ETA: 0s - loss: 0.0039 - accuracy: 0.9989
# Epoch 11: val_accuracy did not improve from 0.97959
# 83/83 [==============================] - 11s 132ms/step - loss: 0.0039 - accuracy: 0.9989 - val_loss: 0.0952 - val_accuracy: 0.9796 - lr: 9.0000e-05
# Epoch 12/12
# 83/83 [==============================] - ETA: 0s - loss: 0.0058 - accuracy: 0.9977
# Epoch 12: val_accuracy did not improve from 0.97959
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# 83/83 [==============================] - 11s 132ms/step - loss: 0.0058 - accuracy: 0.9977 - val_loss: 0.0910 - val_accuracy: 0.9796 - lr: 9.0000e-05

# %%
filterwarnings('ignore')

epochs = [i for i in range(12)]
fig, ax = plt.subplots(1,2,figsize=(14,7))
train_acc = history.history['accuracy']
train_loss = history.history['loss']
val_acc = history.history['val_accuracy']
val_loss = history.history['val_loss']

fig.text(s='Epochs vs. Training and Validation Accuracy/Loss',size=18,fontweight='bold',
             fontname='monospace',color=colors_dark[1],y=1,x=0.28,alpha=0.8)

sns.despine()
ax[0].plot(epochs, train_acc, marker='o',markerfacecolor=colors_green[2],color=colors_green[3],
           label = 'Training Accuracy')
ax[0].plot(epochs, val_acc, marker='o',markerfacecolor=colors_red[2],color=colors_red[3],
           label = 'Validation Accuracy')
ax[0].legend(frameon=False)
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Accuracy')

sns.despine()
ax[1].plot(epochs, train_loss, marker='o',markerfacecolor=colors_green[2],color=colors_green[3],
           label ='Training Loss')
ax[1].plot(epochs, val_loss, marker='o',markerfacecolor=colors_red[2],color=colors_red[3],
           label = 'Validation Loss')
ax[1].legend(frameon=False)
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Training & Validation Loss')

fig.show()

# %% [markdown]
# ---

# %% [markdown]
# # Prediction

# %% [markdown]
# I've used the *argmax function* as each row from the prediction array contains four values for the respective labels. The **maximum** value which is in each row depicts the predicted output out of the 4 possible outcomes.<br>
# So with *argmax*, I'm able to find out the index associated with the predicted outcome.

# %%
pred = model.predict(X_test)
pred = np.argmax(pred,axis=1)
y_test_new = np.argmax(y_test,axis=1)
# Out:
# 11/11 [==============================] - 3s 124ms/step

# %% [markdown]
# ---

# %% [markdown]
# # Evaluation

# %% [markdown]
# In this, <br>
# 0 - Glioma Tumor<br>
# 1 - No Tumor<br>
# 2 - Meningioma Tumor<br>
# 3 - Pituitary Tumor<br>

# %%
print(classification_report(y_test_new,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.92      0.93        93
#            1       0.94      1.00      0.97        51
#            2       0.96      0.95      0.95        96
#            3       1.00      1.00      1.00        87
#
#     accuracy                           0.96       327
#    macro avg       0.96      0.97      0.96       327
# weighted avg       0.96      0.96      0.96       327

# %%
fig,ax=plt.subplots(1,1,figsize=(14,7))
sns.heatmap(confusion_matrix(y_test_new,pred),ax=ax,xticklabels=labels,yticklabels=labels,annot=True,
           cmap=colors_green[::-1],alpha=0.7,linewidths=2,linecolor=colors_dark[3])
fig.text(s='Heatmap of the Confusion Matrix',size=18,fontweight='bold',
             fontname='monospace',color=colors_dark[1],y=0.92,x=0.28,alpha=0.8)

plt.show()

# %% [markdown]
# ---

# %% [markdown]
# # Bonus Content: Widgets

# %% [markdown]
# I've made these Widgets in which we can upload images from our local machine and predict whether the MRI scan has a Brain Tumour or not and to classify which Tumor it is.<br>
# Unfortunately, it doesn't work on Kaggle but you can play around with this by downloading the notebook on your machine :)

# %%
def img_pred(upload):
    for name, file_info in uploader.value.items():
        img = Image.open(io.BytesIO(file_info['content']))
    opencvImage = cv2.cvtColor(np.array(img), cv2.COLOR_RGB2BGR)
    img = cv2.resize(opencvImage,(150,150))
    img = img.reshape(1,150,150,3)
    p = model.predict(img)
    p = np.argmax(p,axis=1)[0]

    if p==0:
        p='Glioma Tumor'
    elif p==1:
        print('The model predicts that there is no tumor')
    elif p==2:
        p='Meningioma Tumor'
    else:
        p='Pituitary Tumor'

    if p!=1:
        print(f'The Model predicts that it is a {p}')

# %% [markdown]
# This is where you can upload the image by clicking on the **Upload** button:

# %%
uploader = widgets.FileUpload()
display(uploader)
# Out:
# FileUpload(value={}, description='Upload')

# %% [markdown]
# After uploading the image, you can click on the **Predict** button below to make predictions:

# %%
button = widgets.Button(description='Predict')
out = widgets.Output()
def on_button_clicked(_):
    with out:
        clear_output()
        try:
            img_pred(uploader)

        except:
            print('No Image Uploaded/Invalid Image File')
button.on_click(on_button_clicked)
widgets.VBox([button,out])
# Out:
# VBox(children=(Button(description='Predict', style=ButtonStyle()), Output()))

# %% [markdown]
# ---

# %% [markdown]
# # Conclusion

# %% [markdown]
# In this notebook, I performed Image Classification with the help of CNN using Transfer Learning which gave an accuracy of around 98%.<br>
# I also made widgets which can make predictions on an image from your local machine!

# %% [markdown]
# ---

# %% [markdown]
# # <center>Thank You!
